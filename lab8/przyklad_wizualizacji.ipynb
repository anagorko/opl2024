# %%
from wizualizacja import rysuj

# %%
a = (1, 0)
b = (0, 1)
c = (2, 3)
d = (-1, 2)

krawedzie = {(a, b), (a, c)}
promienie = {(b, d), (c, d)}

rysuj(krawedzie, promienie)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
p = (1, 0, 0)
q = (0, 1, 0)
r = (0, 0, 1)
s = (1, 1, 1)

krawedzie = {(p, q), (p, r), (p, s), (q, r), (q, s), (r, s)}
promienie = {}

show(rysuj(krawedzie, promienie), viewpoint=([-0.3336,-0.5349,-0.7763],128.33))
# Out:
# Graphics3d Object
